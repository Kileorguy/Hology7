# %%
import os
import tensorflow as tf
import cv2 as cv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization,Conv2D,MaxPooling2D,Activation,Dropout,Lambda,Dense,Flatten, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Concatenate

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
input_shape = (224, 224, 3)
image_size = (224,224)
def preProcess(img):
    img = cv.resize(img, image_size,
               interpolation = cv.INTER_LINEAR)
    # img = to_hsv(img)
    return img


def to_hsv(img):

  hue_shift = 180
  saturation_scale = 2
  value_scale = 5

  # img[..., 0] = (img[..., 0] + hue_shift) % 180
  img[..., 1] = np.clip(img[..., 1] * saturation_scale, 0, 255)
  img[..., 2] = np.clip(img[..., 2] * value_scale, 0, 255)
  img[..., 2] = cv.equalizeHist(img[..., 2])

  img = cv.cvtColor(img, cv.COLOR_HSV2BGR)
  # img = cv.equalizeHist(img)
  return img

# %%
train_dir = './train/'
test_dir = './test/'
train_df = pd.read_csv('./train.csv')

train_data = []
train_jenis = []
train_warna =[]

test_data = []
test_ids = []

for i in os.listdir(train_dir):
    if(i is not None):
        img_path = os.path.join(train_dir, i)
        img = cv.imread(img_path)
        if(img is not None):
          img = preProcess(img)
          train_data.append(img)
          cond = train_df['id'] == int(i[:-4])
          idx = train_df.loc[cond].index[0]
          train_jenis.append(train_df.iloc[idx]['jenis'])
          train_warna.append(train_df.iloc[idx]['warna'])
        else:
          print("no image found")

for i in os.listdir(test_dir):
    if(i is not None):
      img_path = os.path.join(test_dir, i)
      img = cv.imread(img_path)
      if(img is not None):
        img = preProcess(img)
        test_data.append(img)
        test_ids.append(i[:-4])
      else:
        print("no image found")


print(len(train_data))
print(len(train_jenis))
print(len(train_warna))

xtrain_data, xval_data, ytrain_jenis, yval_jenis, ytrain_warna, yval_warna = train_test_split(
    train_data, train_jenis, train_warna, test_size=0.2, random_state=42
)

print(len(test_data))
print(len(test_ids))
# Out:
# 777
# 777
# 777
# 334
# 334

# %%
def plot_image(img):
    plt.imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))
    plt.show()

# %%
def ColorNet(input, nb_class):
    top_conv1 = Conv2D(filters=48,kernel_size=(11,11),strides=(4,4),
                              input_shape=(224,224,3),activation='relu')(input)
    top_conv1 = BatchNormalization()(top_conv1)
    top_conv1 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(top_conv1)

    # second top convolution layer
    # split feature map by half
    top_top_conv2 = Lambda(lambda x : x[:,:,:,:24])(top_conv1)
    top_bot_conv2 = Lambda(lambda x : x[:,:,:,24:])(top_conv1)

    top_top_conv2 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_top_conv2)
    top_top_conv2 = BatchNormalization()(top_top_conv2)
    top_top_conv2 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(top_top_conv2)

    top_bot_conv2 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_bot_conv2)
    top_bot_conv2 = BatchNormalization()(top_bot_conv2)
    top_bot_conv2 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(top_bot_conv2)

    # third top convolution layer
    # concat 2 feature map
    top_conv3 = Concatenate()([top_top_conv2,top_bot_conv2])
    top_conv3 = Conv2D(filters=192,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_conv3)

    # fourth top convolution layer
    # split feature map by half
    top_top_conv4 = Lambda(lambda x : x[:,:,:,:96])(top_conv3)
    top_bot_conv4 = Lambda(lambda x : x[:,:,:,96:])(top_conv3)

    top_top_conv4 = Conv2D(filters=96,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_top_conv4)
    top_bot_conv4 = Conv2D(filters=96,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_bot_conv4)

    # fifth top convolution layer
    top_top_conv5 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_top_conv4)
    top_top_conv5 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(top_top_conv5)

    top_bot_conv5 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(top_bot_conv4)
    top_bot_conv5 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(top_bot_conv5)

    # ============================================= TOP BOTTOM ===================================================
    # first bottom convolution layer
    bottom_conv1 = Conv2D(filters=48,kernel_size=(11,11),strides=(4,4),
                              input_shape=(224,224,3),activation='relu')(input)
    bottom_conv1 = BatchNormalization()(bottom_conv1)
    bottom_conv1 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(bottom_conv1)

    # second bottom convolution layer
    # split feature map by half
    bottom_top_conv2 = Lambda(lambda x : x[:,:,:,:24])(bottom_conv1)
    bottom_bot_conv2 = Lambda(lambda x : x[:,:,:,24:])(bottom_conv1)

    bottom_top_conv2 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_top_conv2)
    bottom_top_conv2 = BatchNormalization()(bottom_top_conv2)
    bottom_top_conv2 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(bottom_top_conv2)

    bottom_bot_conv2 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_bot_conv2)
    bottom_bot_conv2 = BatchNormalization()(bottom_bot_conv2)
    bottom_bot_conv2 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(bottom_bot_conv2)

    # third bottom convolution layer
    # concat 2 feature map
    bottom_conv3 = Concatenate()([bottom_top_conv2,bottom_bot_conv2])
    bottom_conv3 = Conv2D(filters=192,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_conv3)

    # fourth bottom convolution layer
    # split feature map by half
    bottom_top_conv4 = Lambda(lambda x : x[:,:,:,:96])(bottom_conv3)
    bottom_bot_conv4 = Lambda(lambda x : x[:,:,:,96:])(bottom_conv3)

    bottom_top_conv4 = Conv2D(filters=96,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_top_conv4)
    bottom_bot_conv4 = Conv2D(filters=96,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_bot_conv4)

    # fifth bottom convolution layer
    bottom_top_conv5 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_top_conv4)
    bottom_top_conv5 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(bottom_top_conv5)

    bottom_bot_conv5 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),activation='relu',padding='same')(bottom_bot_conv4)
    bottom_bot_conv5 = MaxPooling2D(pool_size=(3,3),strides=(2,2))(bottom_bot_conv5)

    # ======================================== CONCATENATE TOP AND BOTTOM BRANCH =================================
    conv_output = Concatenate()([top_top_conv5,top_bot_conv5,bottom_top_conv5,bottom_bot_conv5])

    flatten = Flatten()(conv_output)

    FC_1 = Dense(units=4096, activation='relu')(flatten)
    FC_1 = Dropout(0.6)(FC_1)
    FC_2 = Dense(units=4096, activation='relu')(FC_1)
    FC_2 = Dropout(0.6)(FC_2)
    output = Dense(units=nb_class)(FC_2)
    output = Activation("softmax")(output)

    return output

# %%
def rgb_to_grayscale(x):
    return tf.image.rgb_to_grayscale(x)

def CategoryNet(input, nb_class):

    # print(input.shape)
    # x = Lambda(rgb_to_grayscale)(input)
    # print("Shape after grayscale conversion:", x.shape)
    # x = Lambda(lambda x: tf.image.grayscale_to_rgb(x))(x)
    x = Conv2D(filters=96, kernel_size=(11, 11), strides=4, padding='valid', activation='relu')(input)


    x = MaxPooling2D(pool_size=(5, 5), strides=(2,2), padding='valid')(x)

    x = Conv2D(filters=256, kernel_size=(5, 5), strides=1, padding='valid', activation='relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2,2), padding='valid')(x)

    x = Conv2D(filters=384, kernel_size=(3, 3), strides=1, padding='valid', activation='relu')(x)
    x = Conv2D(filters=384, kernel_size=(3, 3), strides=1, padding='valid', activation='relu')(x)
    x = Conv2D(filters=256, kernel_size=(3, 3), strides=1, padding='valid', activation='relu')(x)
    # x = Conv2D(filters=256, kernel_size=(3, 3), strides=2, padding='valid', activation='relu')(x)

    x = MaxPooling2D(pool_size=(3, 3), strides=(2,2), padding='valid')(x)

    x = Flatten()(x)
    x = Dense(4096, activation='relu')(x)
    x = Dense(4096, activation='relu')(x)

    x = Dense(nb_class, activation='softmax', name="category_output")(x)

    return x

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2

# Create the base model from the pre-trained model MobileNet V2
base_model = tf.keras.applications.MobileNetV2(input_shape=input_shape,
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False
# base_model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       2 from tensorflow.keras.applications import MobileNetV2
#       4 # Create the base model from the pre-trained model MobileNet V2
# ----> 5 base_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,1),
#       6                                                include_top=False,
#       7                                                weights='imagenet')
#       8 base_model.trainable = False
#       9 base_model.summary()
#
# File g:\App\Anaconda\envs\deep_learning\lib\site-packages\keras\applications\mobilenet_v2.py:300, in MobileNetV2(input_shape, alpha, include_top, weights, input_tensor, pooling, classes, classifier_activation, **kwargs)
#     297     else:
#     298         default_size = 224
# --> 300 input_shape = imagenet_utils.obtain_input_shape(
#     301     input_shape,
#     302     default_size=default_size,
#     303     min_size=32,
#     304     data_format=backend.image_data_format(),
#     305     require_flatten=include_top,
#     306     weights=weights,
#     307 )
#     309 if backend.image_data_format() == "channels_last":
#     310     row_axis, col_axis = (0, 1)
#
# File g:\App\Anaconda\envs\deep_learning\lib\site-packages\keras\applications\imagenet_utils.py:401, in obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     397     raise ValueError(
#     398         "`input_shape` must be a tuple of three integers."
#     399     )
#     400 if input_shape[-1] != 3 and weights == "imagenet":
# --> 401     raise ValueError(
#     402         "The input must have 3 channels; Received "
#     403         f"`input_shape={input_shape}`"
#     404     )
#     405 if (
#     406     input_shape[0] is not None and input_shape[0] < min_size
#     407 ) or (input_shape[1] is not None and input_shape[1] < min_size):
#     408     raise ValueError(
#     409         "Input size must be at least "
#     410         f"{min_size}x{min_size}; Received: "
#     411         f"input_shape={input_shape}"
#     412     )
#
# ValueError: The input must have 3 channels; Received `input_shape=(224, 224, 1)`

# %%
def create_model_warna(num_classes_warna):
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Feature extraction layer
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)

    # Color branch
    color_output = layers.Dense(num_classes_warna, activation='softmax', name='color_output')(x)

    model = Model(inputs=base_model.input, outputs=color_output)
    return model

# %%
def create_model_jenis(num_classes_jenis):
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Feature extraction layer
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)

    # Color branch
    color_output = layers.Dense(num_classes_jenis, activation='softmax', name='color_output')(x)

    model = Model(inputs=base_model.input, outputs=color_output)
    return model

# %%
train_warna_categorical = to_categorical(train_warna,num_classes=len(np.unique(train_warna)))
train_jenis_categorical = to_categorical(train_jenis,num_classes=len(np.unique(train_jenis)))

# xtrain_data, xval_data, ytrain_jenis, yval_jenis, ytrain_warna, yval_warna
ytrain_jenis = to_categorical(ytrain_jenis,num_classes=len(np.unique(ytrain_jenis)))
ytrain_warna = to_categorical(ytrain_warna,num_classes=len(np.unique(ytrain_warna)))
yval_jenis = to_categorical(yval_jenis,num_classes=len(np.unique(yval_jenis)))
yval_warna = to_categorical(yval_warna,num_classes=len(np.unique(yval_warna)))

xtrain_data = np.array(xtrain_data)
xval_data = np.array(xval_data)

print(train_warna_categorical)
print(ytrain_warna)

num_classes_jenis = len(np.unique(train_jenis))
num_classes_warna = len(np.unique(train_warna))

inp = Input(input_shape)

colorBranch = ColorNet(input=inp, nb_class=len(np.unique(train_warna)))
categoryBranch = CategoryNet(input=inp, nb_class=len(np.unique(train_jenis)))

color_model = Model(
			inputs=inp,
			outputs=colorBranch,
            )

category_model = Model(
    inputs=inp,
    outputs=categoryBranch
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 train_warna_categorical = to_categorical(train_warna,num_classes=len(np.unique(train_warna)))
#       2 train_jenis_categorical = to_categorical(train_jenis,num_classes=len(np.unique(train_jenis)))
#       4 # xtrain_data, xval_data, ytrain_jenis, yval_jenis, ytrain_warna, yval_warna
#
# NameError: name 'train_warna' is not defined

# %%
# color_model = ColorNet(input=inp, nb_class=len(np.unique(train_warna)))
category_model = create_model_jenis(num_classes_jenis)
category_model.summary()

# %%
opt = Adam(learning_rate=0.0001)


color_model.compile(optimizer=opt, loss='categorical_crossentropy',
	metrics=['accuracy'])

history = color_model.fit(xtrain_data,ytrain_warna, batch_size= 16, epochs=50,validation_data=(xval_data,yval_warna))
# Out:
# Epoch 1/50
# 39/39 [==============================] - 2s 32ms/step - loss: 1.9446 - accuracy: 0.4267 - val_loss: 0.5546 - val_accuracy: 0.7885
# Epoch 2/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.4948 - accuracy: 0.8132 - val_loss: 0.5331 - val_accuracy: 0.8333
# Epoch 3/50
# 39/39 [==============================] - 1s 27ms/step - loss: 0.3204 - accuracy: 0.8953 - val_loss: 0.2219 - val_accuracy: 0.9103
# Epoch 4/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.2622 - accuracy: 0.9098 - val_loss: 0.1695 - val_accuracy: 0.9679
# Epoch 5/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.2123 - accuracy: 0.9372 - val_loss: 0.2315 - val_accuracy: 0.9295
# Epoch 6/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.1362 - accuracy: 0.9630 - val_loss: 0.2673 - val_accuracy: 0.8654
# Epoch 7/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.1313 - accuracy: 0.9581 - val_loss: 0.1595 - val_accuracy: 0.9615
# Epoch 8/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1160 - accuracy: 0.9646 - val_loss: 0.1247 - val_accuracy: 0.9936
# Epoch 9/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.1154 - accuracy: 0.9662 - val_loss: 0.2408 - val_accuracy: 0.9167
# Epoch 10/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1157 - accuracy: 0.9597 - val_loss: 0.1161 - val_accuracy: 0.9615
# Epoch 11/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.1003 - accuracy: 0.9758 - val_loss: 0.1387 - val_accuracy: 0.9487
# Epoch 12/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0710 - accuracy: 0.9791 - val_loss: 0.0805 - val_accuracy: 0.9872
# Epoch 13/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0807 - accuracy: 0.9726 - val_loss: 0.1255 - val_accuracy: 0.9679
# Epoch 14/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0786 - accuracy: 0.9791 - val_loss: 0.2102 - val_accuracy: 0.9423
# Epoch 15/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0714 - accuracy: 0.9742 - val_loss: 0.0640 - val_accuracy: 0.9936
# Epoch 16/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0800 - accuracy: 0.9839 - val_loss: 0.0896 - val_accuracy: 0.9679
# Epoch 17/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0825 - accuracy: 0.9710 - val_loss: 0.1366 - val_accuracy: 0.9679
# Epoch 18/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0992 - accuracy: 0.9775 - val_loss: 0.0509 - val_accuracy: 0.9936
# Epoch 19/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1098 - accuracy: 0.9678 - val_loss: 0.1776 - val_accuracy: 0.9487
# Epoch 20/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1405 - accuracy: 0.9630 - val_loss: 0.1341 - val_accuracy: 0.9551
# Epoch 21/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1207 - accuracy: 0.9662 - val_loss: 0.1601 - val_accuracy: 0.9679
# Epoch 22/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0761 - accuracy: 0.9758 - val_loss: 0.0954 - val_accuracy: 0.9744
# Epoch 23/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0575 - accuracy: 0.9839 - val_loss: 0.1065 - val_accuracy: 0.9744
# Epoch 24/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0611 - accuracy: 0.9791 - val_loss: 0.1200 - val_accuracy: 0.9679
# Epoch 25/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0301 - accuracy: 0.9903 - val_loss: 0.0651 - val_accuracy: 0.9872
# Epoch 26/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0290 - accuracy: 0.9952 - val_loss: 0.2228 - val_accuracy: 0.9359
# Epoch 27/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0192 - accuracy: 0.9952 - val_loss: 1.2022 - val_accuracy: 0.7885
# Epoch 28/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0392 - accuracy: 0.9871 - val_loss: 0.1439 - val_accuracy: 0.9744
# Epoch 29/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0400 - accuracy: 0.9839 - val_loss: 0.1261 - val_accuracy: 0.9744
# Epoch 30/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0188 - accuracy: 0.9968 - val_loss: 0.0578 - val_accuracy: 0.9936
# Epoch 31/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0753 - accuracy: 0.9742 - val_loss: 0.1664 - val_accuracy: 0.9615
# Epoch 32/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0682 - accuracy: 0.9807 - val_loss: 0.1187 - val_accuracy: 0.9679
# Epoch 33/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.0710 - val_accuracy: 0.9872
# Epoch 34/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0127 - accuracy: 0.9936 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 35/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0264 - accuracy: 0.9936 - val_loss: 0.5281 - val_accuracy: 0.8141
# Epoch 36/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0157 - accuracy: 0.9968 - val_loss: 0.0754 - val_accuracy: 0.9744
# Epoch 37/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0368 - accuracy: 0.9903 - val_loss: 0.2050 - val_accuracy: 0.9295
# Epoch 38/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0169 - accuracy: 0.9936 - val_loss: 0.8538 - val_accuracy: 0.7949
# Epoch 39/50
# 39/39 [==============================] - 1s 24ms/step - loss: 0.0468 - accuracy: 0.9871 - val_loss: 0.0878 - val_accuracy: 0.9808
# Epoch 40/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0347 - accuracy: 0.9887 - val_loss: 0.1587 - val_accuracy: 0.9359
# Epoch 41/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0441 - accuracy: 0.9855 - val_loss: 0.2563 - val_accuracy: 0.8782
# Epoch 42/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1233 - accuracy: 0.9662 - val_loss: 0.2264 - val_accuracy: 0.9167
# Epoch 43/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.0977 - accuracy: 0.9742 - val_loss: 0.2390 - val_accuracy: 0.9615
# Epoch 44/50
# 39/39 [==============================] - 1s 25ms/step - loss: 0.1294 - accuracy: 0.9678 - val_loss: 0.2140 - val_accuracy: 0.9359
# Epoch 45/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0495 - accuracy: 0.9903 - val_loss: 0.2795 - val_accuracy: 0.8910
# Epoch 46/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.1025 - accuracy: 0.9726 - val_loss: 0.7720 - val_accuracy: 0.8141
# Epoch 47/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0553 - accuracy: 0.9839 - val_loss: 0.5482 - val_accuracy: 0.8077
# Epoch 48/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0524 - accuracy: 0.9823 - val_loss: 0.5638 - val_accuracy: 0.8462
# Epoch 49/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0366 - accuracy: 0.9919 - val_loss: 0.2451 - val_accuracy: 0.9103
# Epoch 50/50
# 39/39 [==============================] - 1s 26ms/step - loss: 0.0236 - accuracy: 0.9936 - val_loss: 0.0410 - val_accuracy: 0.9872

# %%
score = color_model.evaluate(xtrain_data,ytrain_warna)

print("Loss and metrics for each output:", score)
# Out:
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0117 - accuracy: 1.0000
# Loss and metrics for each output: [0.011652466841042042, 1.0]

# %%
print('Total Test Loss:', score[0])
print('Color Output Loss:', score[1])

totall = len(history.history['loss'])
totall = len(history.history['loss'])

plt.figure(figsize=(12, 6))

# print(history.history)

plt.subplot(1, 2, 1)
plt.plot(range(totall), history.history['loss'], label='Total Loss')
# plt.plot(range(totall), history.history['category_output_loss'], label='Category Loss')
# plt.plot(range(totall), history.history['color_output_loss'], label='Color Loss')


plt.plot(range(totall), history.history['val_loss'], label='Val Category Loss', linestyle='--')
# plt.plot(range(totall), history.history['val_color_output_loss'], label='Val Color Loss', linestyle='--')

plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')

plt.subplot(1, 2, 2)
plt.plot(range(totall), history.history['accuracy'], label='Color Accuracy')
# plt.plot(range(totall), history.history['color_output_accuracy'], label='Color Accuracy')

plt.plot(range(totall), history.history['val_accuracy'], label='Val Color Accuracy', linestyle='--')
# plt.plot(range(totall), history.history['val_color_output_accuracy'], label='Val Color Accuracy', linestyle='--')


plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')

plt.show()
# Out:
# Total Test Loss: 0.011652466841042042
# Color Output Loss: 1.0

# %%
opt = Adam(learning_rate=0.0001)


category_model.compile(optimizer=opt, loss='categorical_crossentropy',
	metrics=['accuracy'])


history = category_model.fit(xtrain_data,ytrain_jenis, batch_size= 16, epochs=50,validation_data=(xval_data,yval_jenis))
# Out:
# Epoch 1/50
# 39/39 [==============================] - 5s 79ms/step - loss: 0.3951 - accuracy: 0.8261 - val_loss: 0.5740 - val_accuracy: 0.7436
# Epoch 2/50
# 39/39 [==============================] - 3s 65ms/step - loss: 0.0601 - accuracy: 0.9855 - val_loss: 0.5475 - val_accuracy: 0.8013
# Epoch 3/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0483 - accuracy: 0.9839 - val_loss: 0.3260 - val_accuracy: 0.8654
# Epoch 4/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0306 - accuracy: 0.9936 - val_loss: 0.3931 - val_accuracy: 0.8846
# Epoch 5/50
# 39/39 [==============================] - 3s 68ms/step - loss: 0.0231 - accuracy: 0.9952 - val_loss: 0.2460 - val_accuracy: 0.8910
# Epoch 6/50
# 39/39 [==============================] - 3s 67ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2351 - val_accuracy: 0.9038
# Epoch 7/50
# 39/39 [==============================] - 3s 74ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9103
# Epoch 8/50
# 39/39 [==============================] - 3s 67ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9295
# Epoch 9/50
# 39/39 [==============================] - 3s 65ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.1395 - val_accuracy: 0.9295
# Epoch 10/50
# 39/39 [==============================] - 3s 65ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9615
# Epoch 11/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9679
# Epoch 12/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0497 - val_accuracy: 0.9808
# Epoch 13/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 0.9808
# Epoch 14/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9744
# Epoch 15/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9808
# Epoch 16/50
# 39/39 [==============================] - 3s 65ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9936
# Epoch 17/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0669 - val_accuracy: 0.9551
# Epoch 18/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0637 - val_accuracy: 0.9744
# Epoch 19/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0398 - accuracy: 0.9839 - val_loss: 0.1601 - val_accuracy: 0.9487
# Epoch 20/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0346 - accuracy: 0.9839 - val_loss: 0.6208 - val_accuracy: 0.8782
# Epoch 21/50
# 39/39 [==============================] - 2s 63ms/step - loss: 0.0296 - accuracy: 0.9903 - val_loss: 0.6357 - val_accuracy: 0.8590
# Epoch 22/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0269 - accuracy: 0.9919 - val_loss: 0.4161 - val_accuracy: 0.8910
# Epoch 23/50
# 39/39 [==============================] - 3s 65ms/step - loss: 0.0330 - accuracy: 0.9855 - val_loss: 0.3295 - val_accuracy: 0.9359
# Epoch 24/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0171 - accuracy: 0.9936 - val_loss: 0.2115 - val_accuracy: 0.9359
# Epoch 25/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0101 - accuracy: 0.9952 - val_loss: 0.3016 - val_accuracy: 0.9295
# Epoch 26/50
# 39/39 [==============================] - 3s 66ms/step - loss: 0.0071 - accuracy: 0.9968 - val_loss: 0.2557 - val_accuracy: 0.9295
# Epoch 27/50
# 39/39 [==============================] - 2s 64ms/step - loss: 0.0116 - accuracy: 0.9952 - val_loss: 0.4446 - val_accuracy: 0.8974
# Epoch 28/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8974
# Epoch 29/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3888 - val_accuracy: 0.9167
# Epoch 30/50
# 39/39 [==============================] - 2s 62ms/step - loss: 8.0148e-04 - accuracy: 1.0000 - val_loss: 0.3284 - val_accuracy: 0.9231
# Epoch 31/50
# 39/39 [==============================] - 2s 62ms/step - loss: 7.3306e-04 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9359
# Epoch 32/50
# 39/39 [==============================] - 2s 62ms/step - loss: 5.4344e-04 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9359
# Epoch 33/50
# 39/39 [==============================] - 2s 62ms/step - loss: 2.9631e-04 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9295
# Epoch 34/50
# 39/39 [==============================] - 2s 62ms/step - loss: 6.9979e-04 - accuracy: 1.0000 - val_loss: 0.2189 - val_accuracy: 0.9359
# Epoch 35/50
# 39/39 [==============================] - 2s 62ms/step - loss: 3.6760e-04 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9359
# Epoch 36/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9295
# Epoch 37/50
# 39/39 [==============================] - 2s 62ms/step - loss: 3.9277e-04 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9423
# Epoch 38/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9487
# Epoch 39/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9615
# Epoch 40/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9615
# Epoch 41/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0947 - val_accuracy: 0.9615
# Epoch 42/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0354 - accuracy: 0.9968 - val_loss: 0.1436 - val_accuracy: 0.9551
# Epoch 43/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0092 - accuracy: 0.9952 - val_loss: 0.0730 - val_accuracy: 0.9808
# Epoch 44/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0180 - accuracy: 0.9919 - val_loss: 0.1606 - val_accuracy: 0.9615
# Epoch 45/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0068 - accuracy: 0.9952 - val_loss: 0.1050 - val_accuracy: 0.9679
# Epoch 46/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.0844 - val_accuracy: 0.9615
# Epoch 47/50
# 39/39 [==============================] - 2s 63ms/step - loss: 8.0904e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9551
# Epoch 48/50
# 39/39 [==============================] - 2s 62ms/step - loss: 8.1390e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9679
# Epoch 49/50
# 39/39 [==============================] - 2s 62ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9744
# Epoch 50/50
# 39/39 [==============================] - 2s 63ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9744

# %%
score = category_model.evaluate(xtrain_data,ytrain_jenis)

print("Loss and metrics for each output:", score)

print('Total Test Loss:', score[0])
print('Color Output Loss:', score[1])

totall = len(history.history['loss'])


totall = len(history.history['loss'])

plt.figure(figsize=(12, 6))

# print(history.history)

plt.subplot(1, 2, 1)
plt.plot(range(totall), history.history['loss'], label='Total Loss')
# plt.plot(range(totall), history.history['category_output_loss'], label='Category Loss')
# plt.plot(range(totall), history.history['color_output_loss'], label='Color Loss')


plt.plot(range(totall), history.history['val_loss'], label='Val Category Loss', linestyle='--')
# plt.plot(range(totall), history.history['val_color_output_loss'], label='Val Color Loss', linestyle='--')

plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')

plt.subplot(1, 2, 2)
plt.plot(range(totall), history.history['accuracy'], label='Color Accuracy')
# plt.plot(range(totall), history.history['color_output_accuracy'], label='Color Accuracy')

plt.plot(range(totall), history.history['val_accuracy'], label='Val Color Accuracy', linestyle='--')
# plt.plot(range(totall), history.history['val_color_output_accuracy'], label='Val Color Accuracy', linestyle='--')


plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')

plt.show()
# Out:
# 20/20 [==============================] - 1s 26ms/step - loss: 1.3420e-06 - accuracy: 1.0000
# Loss and metrics for each output: [1.3419640936263022e-06, 1.0]
# Total Test Loss: 1.3419640936263022e-06
# Color Output Loss: 1.0

# %%
print(test_data[0].shape)
test_data = np.array(test_data)
prediction_jenis = category_model.predict(test_data)
prediction_warna = color_model.predict(test_data)

final_jenis = []
final_warna = []

for p_jenis, p_warna in zip(prediction_jenis,prediction_warna):
    # print(id)
    final_jenis.append(np.argmax(p_jenis))
    final_warna.append(np.argmax(p_warna))
    # print("============")
final = pd.DataFrame({'id':test_ids, 'jenis': final_jenis,'warna': final_warna})
# display(final)
final.to_csv('submission.csv', index=False)
# Out:
# (224, 224, 3)
# 11/11 [==============================] - 1s 25ms/step
# 11/11 [==============================] - 0s 14ms/step
